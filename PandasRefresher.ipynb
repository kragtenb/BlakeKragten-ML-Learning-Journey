# %% [markdown]
# <a href="https://colab.research.google.com/github/kragtenb/SelfDriving-RC-deep-learning/blob/main/PandasRefresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Fundamentals

# %%
import pandas as pd

my_series = pd.Series([1, 5, -3, 8], index=['a', 'b', 'c', 'd'])
print(my_series)
# Out:
# a    1
# b    5
# c   -3
# d    8
# dtype: int64

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [28, 35, 22],
        'City': ['New York', 'London', 'Paris']}

my_dataframe = pd.DataFrame(data)
print(my_dataframe)
# Out:
#       Name  Age      City
# 0    Alice   28  New York
# 1      Bob   35    London
# 2  Charlie   22     Paris

# %% [markdown]
# # Create DataFrames:
#
# 1. Create a simple DataFrame containing information about a few fictional products – name, price, quantity in stock.

# %%
data = {
    'Name': ['Kaladin', 'Hoid', 'Dalanar'],
    'Order': ['Windrunner', 'Lightweaver', 'Bondsmith'],
    'Spren': ['Honor Spren', 'Cryptic', 'God Spren?']
}

dataframe = pd.DataFrame(data)
dataframe
# Out:
#       Name        Order        Spren
# 0  Kaladin   Windrunner  Honor Spren
# 1     Hoid  Lightweaver      Cryptic
# 2  Dalanar    Bondsmith   God Spren?

# %% [markdown]
# # Accessing Data
#
# 1. Select a single column from your DataFrame (as a Series).
# 2. Select a specific value using indexing (e.g., using .loc or .iloc).
# 3. Filter the DataFrame based on a condition (e.g., products priced above a certain value).

# %%
name_series = pd.Series(['Kaladin', 'Hoid', 'Dalanar'])

dataframe.loc[0]
# Out:
# Name         Kaladin
# Order     Windrunner
# Spren    Honor Spren
# Name: 0, dtype: object

# %%
dataframe[:1]
# Out:
#       Name       Order        Spren
# 0  Kaladin  Windrunner  Honor Spren

# %%
dataframe.iloc[1,0]
# Out:
# 'Hoid'

# %%
# Create a dictionary where each key represents a column name and the value is a list containing the column's data
data = {
    'Product Name': ['Phone Case', 'Headphones', 'Laptop'],
    'Price': [20.99, 39.95, 799.00],
    'Quantity': [100, 50, 25]
}

# Create the DataFrame using pd.DataFrame(dictionary)
df = pd.DataFrame(data)
print(df)
# Out:
#   Product Name   Price  Quantity
# 0   Phone Case   20.99       100
# 1   Headphones   39.95        50
# 2       Laptop  799.00        25

# %%
greater = df['Price'] > 21
greater
# Out:
# 0    False
# 1     True
# 2     True
# Name: Price, dtype: bool

# %%
df[greater]
# Out:
#   Product Name   Price  Quantity
# 1   Headphones   39.95        50
# 2       Laptop  799.00        25

# %% [markdown]
# # Data Loading, Cleaning, & Manipulation
#
# ## Real-World Data:
#
# 1. Find a CSV or Excel dataset online on a topic of interest (e.g., Kaggle: https://www.kaggle.com/datasets).
# 2. Load it into a Pandas DataFrame.

# %%
ls
# Out:
# BlueLineFollowingRC.py               HWTutorials/              OpenCvTests.py
# DrivableVisionModel/                 KeyboardControl.py        RCFunctionality/
# DrivingModelTraining.ipynb           LabeledTraining/          RcHelloWorld.py
# grayscale_image.jpg                  LED/                      TrainingData/
# heart_attack_prediction_dataset.csv  local_colab_runtime.bash

# %%
heart_attack_prediction_dataset = pd.read_csv('heart_attack_prediction_dataset.csv')
heart_attack_prediction_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
heart_attack_prediction_dataset.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %% [markdown]
# # Exploration and Cleaning:
#
# Use .info(), .describe(), isnull().sum() to explore the dataset.
# Handle any missing data as necessary.

# %% [markdown]
# # Manipulation and Insights:
#
# 1. Create new columns based on calculations with existing ones.
# 2. Group the data by a categorical column and calculate relevant summary statistics.

# %%
heart_attack_prediction_dataset.isnull()
# Out:
#       Patient ID    Age    Sex  Cholesterol  Blood Pressure  Heart Rate  \
# 0          False  False  False        False           False       False
# 1          False  False  False        False           False       False
# 2          False  False  False        False           False       False
# 3          False  False  False        False           False       False
# 4          False  False  False        False           False       False
# ...          ...    ...    ...          ...             ...         ...
# 8758       False  False  False        False           False       False
# 8759       False  False  False        False           False       False
# 8760       False  False  False        False           False       False
# 8761       False  False  False        False           False       False
# 8762       False  False  False        False           False       False
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# ...

# %%
# Add column more than 10 hours per week of exercise
heart_attack_prediction_dataset['High Exercise User'] = heart_attack_prediction_dataset['Exercise Hours Per Week'] > 10

# %%
heart_attack_prediction_dataset
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  Income        BMI  \
# ...

# %%
heart_attack_prediction_dataset.groupby('High Exercise User')['Alcohol Consumption'].mean()
# Out:
# High Exercise User
# False    0.601379
# True     0.594833
# Name: Alcohol Consumption, dtype: float64

# %% [markdown]
# # Date/Time Handling, Sorting, & Merging

# %%
pd.to_datetime('02/15/1998 07:32:30').hour
# Out:
# 7

# %%
heart_attack_prediction_dataset.sort_values(by='Patient ID')
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 7398    AAA9246   61    Male          171         148/90          89
# 1018    AAC3641   57  Female          232         144/93          73
# 975     AAD0466   20  Female          357         159/91          75
# 3221    AAD3011   21    Male          165        106/103          76
# 4583    AAE4089   52  Female          335         165/63          43
# ...         ...  ...     ...          ...            ...         ...
# 2966    ZZI5174   19    Male          143         167/93          57
# 203     ZZQ4895   49    Male          279         177/70          86
# 7468    ZZT7113   49  Female          297         158/88          69
# 6179    ZZU2948   25  Female          238         136/76          81
# 3110    ZZY4724   35    Male          352         157/67          81
#
#       Diabetes  Family History  Smoking  Obesity  ...  Income        BMI  \
# ...

# %%
males = heart_attack_prediction_dataset[heart_attack_prediction_dataset['Sex'] == 'Male']
females = heart_attack_prediction_dataset[heart_attack_prediction_dataset['Sex'] == 'Female']

# %%
males
# Out:
#      Patient ID  Age   Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0       BMW7812   67  Male          208         158/88          72         0
# 1       CZE1114   21  Male          389         165/93          98         1
# 3       JLN3497   84  Male          383        163/100          73         1
# 4       GFO8847   66  Male          318          91/88          93         1
# 6       WYV0966   90  Male          358         102/73          84         0
# ...         ...  ...   ...          ...            ...         ...       ...
# 8755    KQR8949   25  Male          307         137/94          78         0
# 8756    BUE0416   22  Male          347         115/87         108         0
# 8758    MSV9918   60  Male          121          94/76          61         1
# 8760    XKA5925   47  Male          250         161/75         105         0
# 8761    EPE6801   36  Male          178         119/67          60         1
#
# ...

# %%
females
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 2       BNI9906   21  Female          324         174/99          72
# 5       ZOO7941   54  Female          297         172/86          48
# 9       FTJ5456   43  Female          248         160/70          55
# 10      HSD6283   73  Female          373         107/69          97
# 18      XBI0592   50  Female          303        120/100         104
# ...         ...  ...     ...          ...            ...         ...
# 8750    FDK8693   34  Female          304         102/92          93
# 8754    LZM3606   80  Female          383         153/96          91
# 8757    YDX2478   59  Female          378          93/78          99
# 8759    QSV6764   28  Female          120        157/102          73
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  Income        BMI  \
# ...

# %%
merged_back = pd.merge(males, females, how='outer')

# %%
merged_back
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       AAA9246   61    Male          171         148/90          89
# 1       AAC3641   57  Female          232         144/93          73
# 2       AAD0466   20  Female          357         159/91          75
# 3       AAD3011   21    Male          165        106/103          76
# 4       AAE4089   52  Female          335         165/63          43
# ...         ...  ...     ...          ...            ...         ...
# 8758    ZZI5174   19    Male          143         167/93          57
# 8759    ZZQ4895   49    Male          279         177/70          86
# 8760    ZZT7113   49  Female          297         158/88          69
# 8761    ZZU2948   25  Female          238         136/76          81
# 8762    ZZY4724   35    Male          352         157/67          81
#
#       Diabetes  Family History  Smoking  Obesity  ...  Income        BMI  \
# ...

# %% [markdown]
# #  Advanced Pandas & Practice

# %%
heart_attack_prediction_dataset.apply(lambda x: "x * 0", axis=1)
# Out:
# 0       x * 0
# 1       x * 0
# 2       x * 0
# 3       x * 0
# 4       x * 0
#         ...
# 8758    x * 0
# 8759    x * 0
# 8760    x * 0
# 8761    x * 0
# 8762    x * 0
# Length: 8763, dtype: object

# %%
heart_attack_prediction_dataset
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  Income        BMI  \
# ...

# %%
def apply_discount(row):
    if row['Age'] > 5:
        row['Heart Rate'] = 0  # 20% discount
    return row

def set_average_age(col):
  return ['Yes', 'No']

result = heart_attack_prediction_dataset.apply(set_average_age, axis=1)  # Apply to each row
print(result)
# Out:
# 0       [Yes, No]
# 1       [Yes, No]
# 2       [Yes, No]
# 3       [Yes, No]
# 4       [Yes, No]
#           ...
# 8758    [Yes, No]
# 8759    [Yes, No]
# 8760    [Yes, No]
# 8761    [Yes, No]
# 8762    [Yes, No]
# Length: 8763, dtype: object

# %%
heart_attack_prediction_dataset.pivot_table(columns='Age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
# ...

# %%
heart_attack_prediction_dataset
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  Income        BMI  \
# ...

# %%
heart_attack_prediction_dataset.sort_values('Age')['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# plt.figure()

plt.plot(heart_attack_prediction_dataset[:5]['Age'], color='Red', marker='x', linestyle='-', linewidth=1)
plt.plot(heart_attack_prediction_dataset[:5]['Heart Rate'], color='Blue', marker='x', linestyle='-', linewidth=1)
plt.legend(labels=['Age', 'Heart Rate'])
plt.title('Age Histogram')
plt.grid(True)

plt.xlabel('Age')
plt.ylabel('Total People')


plt.show()

# %%
# ... (Continuing from previous example)

# Styling
df.plot(x='Month', y='Sales', kind='line', color='red', marker='s', linewidth=3)
plt.grid(True)

# Subplots
fig, axes = plt.subplots(nrows=1, ncols=2)
df['Sales'].plot(kind='hist', ax=axes[0])
df['Sales'].plot(kind='box', ax=axes[1])
plt.show()
