# %% [markdown]
# <a href="https://colab.research.google.com/github/kragtenb/SelfDriving-RC-deep-learning/blob/main/PandasRefresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Fundamentals

# %%
import pandas as pd

my_series = pd.Series([1, 5, -3, 8], index=['a', 'b', 'c', 'd'])
print(my_series)
# Out:
# a    1
# b    5
# c   -3
# d    8
# dtype: int64

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [28, 35, 22],
        'City': ['New York', 'London', 'Paris']}

my_dataframe = pd.DataFrame(data)
print(my_dataframe)
# Out:
#       Name  Age      City
# 0    Alice   28  New York
# 1      Bob   35    London
# 2  Charlie   22     Paris

# %% [markdown]
# # Create DataFrames:
#
# 1. Create a simple DataFrame containing information about a few fictional products – name, price, quantity in stock.

# %%
data = {
    'Name': ['Kaladin', 'Hoid', 'Dalanar'],
    'Order': ['Windrunner', 'Lightweaver', 'Bondsmith'],
    'Spren': ['Honor Spren', 'Cryptic', 'God Spren?']
}

dataframe = pd.DataFrame(data)
dataframe
# Out:
#       Name        Order        Spren
# 0  Kaladin   Windrunner  Honor Spren
# 1     Hoid  Lightweaver      Cryptic
# 2  Dalanar    Bondsmith   God Spren?

# %% [markdown]
# # Accessing Data
#
# 1. Select a single column from your DataFrame (as a Series).
# 2. Select a specific value using indexing (e.g., using .loc or .iloc).
# 3. Filter the DataFrame based on a condition (e.g., products priced above a certain value).

# %%
name_series = pd.Series(['Kaladin', 'Hoid', 'Dalanar'])

dataframe.loc[0]
# Out:
# Name         Kaladin
# Order     Windrunner
# Spren    Honor Spren
# Name: 0, dtype: object

# %%
dataframe[:1]
# Out:
#       Name       Order        Spren
# 0  Kaladin  Windrunner  Honor Spren

# %%
dataframe.iloc[1,0]
# Out:
# 'Hoid'

# %%
# Create a dictionary where each key represents a column name and the value is a list containing the column's data
data = {
    'Product Name': ['Phone Case', 'Headphones', 'Laptop'],
    'Price': [20.99, 39.95, 799.00],
    'Quantity': [100, 50, 25]
}

# Create the DataFrame using pd.DataFrame(dictionary)
df = pd.DataFrame(data)
print(df)
# Out:
#   Product Name   Price  Quantity
# 0   Phone Case   20.99       100
# 1   Headphones   39.95        50
# 2       Laptop  799.00        25

# %%
greater = df['Price'] > 21
greater
# Out:
# 0    False
# 1     True
# 2     True
# Name: Price, dtype: bool

# %%
df[greater]
# Out:
#   Product Name   Price  Quantity
# 1   Headphones   39.95        50
# 2       Laptop  799.00        25
